# %%
import pandas as pd
import numpy as np
import json
df= pd.read_csv('twitter-archive-enhanced.csv')

# %%
df.dtypes
# Out:
# tweet_id                      float64
# in_reply_to_status_id         float64
# in_reply_to_user_id           float64
# timestamp                      object
# source                         object
# text                           object
# retweeted_status_id           float64
# retweeted_status_user_id      float64
# retweeted_status_timestamp     object
# expanded_urls                  object
# rating_numerator                int64
# rating_denominator              int64
# name                           object
# doggo                          object
# floofer                        object
# pupper                         object
# puppo                          object
# dtype: object

# %%
df.retweeted_status_timestamp.sample(10)
# Out:
# 158                           NaN
# 514                           NaN
# 58                            NaN
# 686     2016-08-04 01:03:17 +0000
# 1461                          NaN
# 1398                          NaN
# 956                           NaN
# 2004                          NaN
# 454                           NaN
# 1794                          NaN
# Name: retweeted_status_timestamp, dtype: object

# %%
df.retweeted_status_timestamp.value_counts().value_counts()
# Out:
# 1    181
# Name: retweeted_status_timestamp, dtype: int64

# %%
tweet_id = []
with open('tweet_json.txt', mode='r') as f:
    for tweet_data in f:
        
        json_obj = json.loads(tweet_data)
        #print(type(json_obj))
        #print(type(json_obj['entities']))
        #print(type(json_obj['entities']['media']))
        #print(type(json_obj['entities']['media'][0]))
        #print(type(json_obj['entities']['media'][0].keys())
        #print(json['entities'])
        tweet_id.append(json_obj['id'])

# %%
tweet_id = pd.Series(tweet_id)

# %%
tweet_id.shape
# Out:
# (1993,)

# %%
names = []
with open('tweet_json.txt', mode='r') as f:
    for tweet_data in f:
    
        json_obj = json.loads(tweet_data)
        names.append(json_obj['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-2e7d4eb26b12> in <module>()
#       4
#       5         json_obj = json.loads(tweet_data)
# ----> 6         names.append(json_obj['name'])
#
# KeyError: 'name'

# %%
fav_count
# Out:
# [38674,
#  33136,
#  24948,
#  42054,
#  40214,
#  20164,
#  11814,
#  65321,
#  27707,
#  31851,
#  30579,
#  27716,
#  47983,
#  27102,
#  15047,
#  25227,
#  28997,
#  25519,
#  19848,
#  68924,
#  21696,
#  30103,
#  46114,
#  33583,
#  30451,
#  35057,
#  12036,
#  22358,
#  21145,
#  27902,
#  32601,
#  35896,
#  71743,
#  21895,
#  77282,
#  27852,
#  24231,
#  26913,
#  20333,
#  21843,
#  45846,
#  22512,
#  37125,
#  23895,
#  28246,
#  27830,
#  44878,
#  29278,
#  24234,
#  50446,
#  49335,
#  23018,
#  16970,
#  21245,
#  28452,
#  27008,
#  27560,
#  22253,
#  23352,
#  105659,
#  16738,
#  41970,
#  22542,
#  18921,
#  19366,
#  7742,
#  21575,
#  79710,
#  22702,
#  27316,
#  27084,
#  20630,
#  18735,
#  27873,
#  25166,
#  21893,
#  25455,
#  27821,
#  53364,
#  26058,
#  22648,
#  34672,
#  66251,
#  24246,
#  7253,
#  27406,
#  14731,
#  20815,
#  40759,
#  34300,
#  34524,
#  38164,
#  20316,
#  20280,
#  24317,
#  22745,
#  33798,
#  12487,
#  83141,
#  21941,
# ...

# %%
fav_count = pd.Series(fav_count)
fav_count.shape
# Out:
# (1993,)

# %%
retweet_count = []
with open('tweet_json.txt', mode='r') as f:
    for tweet_data in f:
        
        json_obj = json.loads(tweet_data)
        retweet_count.append(json_obj['retweet_count'])

# %%
retweet_count = pd.Series(retweet_count)
retweet_count.shape
# Out:
# (1993,)

# %%
tweet_id.shape
# Out:
# (1993,)

# %%
df = [tweet_id, retweet_count, fav_count]

# %%
df = pd.concat(df, axis=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.names=['tweet_id', 'retweet_count', 'fav_count']
# Out:
# C:\Users\srijon sarkar\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   if __name__ == '__main__':

# %%
df.columns=['tweet_id', 'retweet_count', 'fav_count']

# %%
df.shape
# Out:
# (1993, 3)

# %%
df.head()
# Out:
#              tweet_id  retweet_count  fav_count
# 0  892420643555336193           8555      38674
# 1  892177421306343426           6288      33136
# 2  891815181378084864           4171      24948
# 3  891689557279858688           8676      42054
# 4  891327558926688256           9444      40214

# %%
df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
df.sample(3)
# Out:
#           tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2045  6.715290e+17                    NaN                  NaN
# 489   8.139100e+17                    NaN                  NaN
# 518   8.106580e+17                    NaN                  NaN
#
#                       timestamp  \
# 2045  2015-12-01 03:18:27 +0000
# 489   2016-12-28 00:52:25 +0000
# 518   2016-12-19 01:26:42 +0000
#
#                                                  source  \
# 2045  <a href="http://twitter.com/download/iphone" r...
# 489   <a href="http://twitter.com/download/iphone" r...
# 518   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2045  Meet Jax. He's in the middle of a serious conv...                  NaN
# 489   This is Chubbs. He dug a hole and now he's stu...                  NaN
# 518   This is Pavlov. His floatation device has fail...                  NaN
#
# ...

# %%
df.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
df.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
t = df.text.sample(5)
for l in t:
    print(l)
# Out:
# RT @dog_rates: This is Nollie. She's waving at you. If you don't wave back you're a monster. She's also portable as hell. 12/10 https://t.c…
# This is Tebow. He kindly requests that you put down the coffee and play with him. 13/10 such a good boy https://t.co/56uBP28eqw
# This is Link. He struggles with couches. 10/10 would assist https://t.co/SbX4e6Yg3o
# This is Longfellow (prolly sophisticated). He's a North Appalachian Oatzenjammer. Concerned about wrinkled feets. 12/10 would hug softly https://t.co/bpLuQuxzHZ
# Meet Al Cabone. He's a gangsta puppa. Rather h*ckin ruthless. Shows no mercy sometimes. 11/10 pet w extreme caution https://t.co/OUwWbEKOUV
